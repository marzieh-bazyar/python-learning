# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Homework01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = dict(name = 'John', age = '36', country = 'Norway')
print(student)
len(student)
type(student)
print(list(student))
print(student.keys())
print(student.values())
print(student.items())
student.update({'name': 'Sara', 'age': 28})
print(student)
print(student.get('name'))
student['name']
numbers = [2, 3, 4, 5]
new_numbers = [val **2 for val in numbers]
print(new_numbers)
new_numbers = [val for val in numbers if val %2 == 0]
print(new_numbers)
# Out:
# {'name': 'John', 'age': '36', 'country': 'Norway'}
# ['name', 'age', 'country']
# dict_keys(['name', 'age', 'country'])
# dict_values(['John', '36', 'Norway'])
# dict_items([('name', 'John'), ('age', '36'), ('country', 'Norway')])
# {'name': 'Sara', 'age': 28, 'country': 'Norway'}
# Sara
# [4, 9, 16, 25]
# [2, 4]

# %%
student = dict(name = 'John', age = '36', country = 'Norway')
print(student)
len(student)
type(student)
print(list(student))
print(student.keys())
print(student.values())
print(student.items())
student.update({'name': 'Sara', 'age': 28})
print(student)
print(student.get('name'))
student['name']
numbers = [2, 3, 4, 5]
new_numbers = [val **2 for val in numbers]
print(new_numbers)
new_numbers = [val for val in numbers if val %2 == 0]
print(new_numbers)
# Out:
# {'name': 'John', 'age': '36', 'country': 'Norway'}
# ['name', 'age', 'country']
# dict_keys(['name', 'age', 'country'])
# dict_values(['John', '36', 'Norway'])
# dict_items([('name', 'John'), ('age', '36'), ('country', 'Norway')])
# {'name': 'Sara', 'age': 28, 'country': 'Norway'}
# Sara
# [4, 9, 16, 25]
# [2, 4]

# %%
student = dict(name = 'John', age = '36', country = 'Norway')
print(student)
len(student)
type(student)
print(list(student))
print(student.keys())
print(student.values())
print(student.items())
student.update({'name': 'Sara', 'age': 28})
print(student)
print(student.get('name'))
student['name']
numbers = [2, 3, 4, 5]
new_numbers = [val **2 for val in numbers]
print(new_numbers)
new_numbers = [val for val in numbers if val %2 == 0]
print(new_numbers)
new_numbers = [val for val in numbers if val %2 != 0]
print(new_numbers)
for key in student:
  print(key)
# Out:
# {'name': 'John', 'age': '36', 'country': 'Norway'}
# ['name', 'age', 'country']
# dict_keys(['name', 'age', 'country'])
# dict_values(['John', '36', 'Norway'])
# dict_items([('name', 'John'), ('age', '36'), ('country', 'Norway')])
# {'name': 'Sara', 'age': 28, 'country': 'Norway'}
# Sara
# [4, 9, 16, 25]
# [2, 4]
# [3, 5]
# name
# age
# country
