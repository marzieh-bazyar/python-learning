# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Homework02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 47
if i <= 47:
   print('it is small')
print()
age = 17
if age >= 18:
    print('You are old enough to vote!')
print()
if age >= 18:
    print('You are old enough to vote!')
    print('Have you registered to vote?')
print()
if age >= 18:
    print('You are old enough to vote!')
    print('Have you registered to vote?')
else:
    print('Sorry, you are young to vote.')
    print('Please register to vote as soon as you turn 18!')
print()
num = -20
if num >= 0:
    print('It is a whole number')
else:
    print('Number is negative')
print()
# Out:
# it is small
#
#
#
# Sorry, you are young to vote.
# Please register to vote as soon as you turn 18!
#
# Number is negative
