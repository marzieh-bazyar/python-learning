# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Homework03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cars = ['BMW', 'Benz', 'Ford', 'Ferarri']
print(cars)
print(type(cars))
x =['name', 1.0, complex(3,4), True, False]
print(x)
print(type(x))
print(len(x))
fruit = ['apple', 'garlic', 'orange', 'pineapple', 'mango']
print(type(fruit))
print(fruit[1])
print(fruit[-1])
print(fruit[1:4])
print(fruit[1:3])
print(fruit[:1])
print(fruit[1:])
print(fruit[0:5:2])
print(fruit[::3])
print(fruit[::-1])
print(fruit[2:])
print(fruit[:8])
print(fruit[7:9])
print(fruit)
print(fruit[0].title())
print(fruit[0].upper())
print(fruit[0].upper().lower())
fruit[0] = 'banana'
print(fruit)
fruit.append('apple')
print(fruit)
fruit.append('apple')
print(fruit)
fruit.insert(1, 'dragon')
print(fruit)
fruit.remove('banana')
print(fruit)
fruit.pop()
print(fruit)
fruit.pop(2)
print(fruit)
fruit.sort()
print(fruit)
print(sorted(fruit))
print(fruit)
fruit.reverse()
print(fruit)
names = ['Ali', 'Sara', 'Reza', 'Mina', 'Amir']
names.pop(2)
print(names)
del names[-2]
print(names)
names.remove('Sara')
print(names)
# Out:
# ['BMW', 'Benz', 'Ford', 'Ferarri']
# <class 'list'>
# ['name', 1.0, (3+4j), True, False]
# <class 'list'>
# 5
# <class 'list'>
# garlic
# mango
# ['garlic', 'orange', 'pineapple']
# ['garlic', 'orange']
# ['apple']
# ['garlic', 'orange', 'pineapple', 'mango']
# ['apple', 'orange', 'mango']
# ['apple', 'pineapple']
# ['mango', 'pineapple', 'orange', 'garlic', 'apple']
# ['orange', 'pineapple', 'mango']
# ['apple', 'garlic', 'orange', 'pineapple', 'mango']
# []
# ['apple', 'garlic', 'orange', 'pineapple', 'mango']
# Apple
# APPLE
# apple
# ['banana', 'garlic', 'orange', 'pineapple', 'mango']
# ['banana', 'garlic', 'orange', 'pineapple', 'mango', 'apple']
# ['banana', 'garlic', 'orange', 'pineapple', 'mango', 'apple', 'apple']
# ['banana', 'dragon', 'garlic', 'orange', 'pineapple', 'mango', 'apple', 'apple']
# ['dragon', 'garlic', 'orange', 'pineapple', 'mango', 'apple', 'apple']
# ['dragon', 'garlic', 'orange', 'pineapple', 'mango', 'apple']
# ...
