# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Homework06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_average(numbers):
    """
    Calculate and return the average of a list of numbers.
    If the list is empty, return 0.
    """

    result = []

    for number in numbers:
        result.append(float(number))

    if not result:
        return 0
    else:
        return sum(result) / len(result)


numbers = input("Enter your scores, please: ").split()

print(calculate_average(numbers))
# Out:
# Enter your scores, please: 14 15 16.5 18 19.5
# 16.6
