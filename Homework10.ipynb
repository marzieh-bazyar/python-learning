# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Homework10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_even(number):
        if number %2 == 0:
             return True
        else:
             return False
while True:
        number = int(input("Enter a number: "))
        print(is_even(number))
