# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Homework13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
secret_number = random.randint(1, 20)
attempts = 0
counter = []
while True:
     guess = int(input("Guess a number between 1 and 20: "))
     attempts += 1
     if len(counter) >= 5:
         print("🚩Game Over!!You Lost!")
         break
     if guess in counter:
         print("🧐You already guessed this number!")
     counter.append(guess)
     print(f"guess list: {counter}")
     if guess < secret_number:
         print("Too low")
     elif guess > secret_number:
         print("Too high")
     else:
        print("You win")
        print("Attempts:", attempts)
        break
