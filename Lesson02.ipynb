# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Lesson02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
buy_home =\
{
    # int type
    'code' : 115,
    # str type
    'age': 70,
    'name' : 'Mohammad Fakhralami',
    # list type
    'dairy': ['milk', 'cheese'],
    'fruit': ['apple', 'potato', 'onion', 'tomato', 'avocado', 'blueberry'],
    # food type string
    'food' : 'Pizza',
    'supermarket':['شکلات', 'چيپس'],
    # location dictionary
    'location':
    {
        'number': 26,
        'street': 'dehghan vila',
        'alley': 'vila 2'
    }
}

if buy_home['age'] < 18:
    print('under 18')
    if 'شکلات' in buy_home['supermarket']:
        print('شکلات not found')
elif buy_home['age'] >= 18 and buy_home['age'] < 80:
    print('adult')
    if buy_home['age'] >= 18 and buy_home['age'] < 30:
        print('جوان')
    elif buy_home['age'] >= 30 and buy_home['age'] < 60:
        print('ميانسال')
    else:
        print('پير')
else:
    print('not found')
# Out:
# adult
# پير
