# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Lesson03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
collage = {
    'Students' : ['Tommy','Andy'],
    'Teacher' : 'alami',
    'Course' : 'English',
    'Room' : '1'
    }
print(collage['Student'][0])
print(collage['Student'][1])
for name in collage['Students']:
    print(name)
for idx in range(len(collage['Students'])):
    print(collage['Students'][idx])

for i in range(7):
  if i%2 == 0:
     print(i,'It is even')
  else:
      print(i,'It is odd')

name = 'Ahmad'
for char in name:
    print(char)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_804/1899491134.py in <cell line: 0>()
#       5     'Room' : '1'
#       6     }
# ----> 7 print(collage['Student'][0])
#       8 print(collage['Student'][1])
#       9 for name in collage['Students']:
#
# KeyError: 'Student'
