# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Lesson03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
collage = {
    'Students' : ['Tommy','Andy'],
    'Teacher' : 'alami',
    'Course' : 'English',
    'Room' : '1'
    }
print(collage['Students'][0])
print(collage['Students'][1])
for name in collage['Students']:
    print(name)
for idx in range(len(collage['Students'])):
    print(collage['Students'][idx])

for i in range(7):
  if i%2 == 0:
     print(i,'It is even')
  else:
      print(i,'It is odd')

name = 'Ahmad'
for char in name:
    print(char)
collage = {
    'Student' : 'Kami',
    'Teacher' : 'alami',
    'Course' : 'English',
    'Room' : '1'
    }

if collage['Room'] == '2':
    print('Done if 1')
elif collage['Course'] == 'Python':
    print('DONE if 2')
else:
    print('Done else')
print('Out of if-else')
n = 0
while n <=5:
    if n ==3:
       print('عدد 3 پيدا شد')
    else:
        print('عدد 3 پيدا نشد')
    n+=1
numbers= [12, 5, 8, 12, 7, 5, 20, 8]
even = []
odd = []
for num in numbers:
    if num % 2==0:
        even.append(num)
        print(f'{num} is even')
    else:
        odd.append(num)
        print(f'{num} is odd')
print(f'sum of evens: {sum(even)}')
print(f'sum of odds: {sum(odd)}')
if sum(even) <= sum(odd):
    print('it is bigger')
# Out:
# Tommy
# Andy
# Tommy
# Andy
# Tommy
# Andy
# 0 It is even
# 1 It is odd
# 2 It is even
# 3 It is odd
# 4 It is even
# 5 It is odd
# 6 It is even
# A
# h
# m
# a
# d
# Done else
# Out of if-else
# عدد 3 پيدا نشد
# عدد 3 پيدا نشد
# عدد 3 پيدا نشد
# عدد 3 پيدا شد
# عدد 3 پيدا نشد
# عدد 3 پيدا نشد
# 12 is even
# 5 is odd
# 8 is even
# 12 is even
# 7 is odd
# 5 is odd
# 20 is even
# 8 is even
# sum of evens: 60
# sum of odds: 17
