# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Lesson04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
buy_home =\
{
    # int type
    'code' : 115,
    # str type
    'name' : 'Mohammad Fakhralami',
    # list type
    'dairy': ['milk', 'cheese'],
    'fruit': ['apple', 'potato', 'onion', 'tomato', 'avocado', 'blueberry'],
    # food type string
    'food' : 'Pizza',
    # location dictionary
    'location':
    {
        'number': 26,
        'street': 'dehghan vila',
        'alley': 'vila 2'
    }
}


# print(f'buy_home: {buy_home}')
buy_home['username'] = 'fakhralami'
# print(f'buy_home new: {buy_home}')
#print(f'dairy list: {buy_home["dairy"]}')
del buy_home['username']
#print(f'buy_home new new: {buy_home}')
buy_home['location'].pop('street')
#print(buy_home)
buy_home['food'] = 'kebab'
#print(buy_home)
buy_home['dairy'].append('yoghurt')
print(buy_home)



# Q-1 Data Type
print('Q-1 Data Type')
numbers = [12, 7, 12, 3, 7,9,1,1,12]
print(f'1-1: count 12 = {numbers.count(12)}')
print(f'1-2: sort list = {sorted(numbers)}\n     Real list = {numbers}')
print(f'1-3: first index 7 = {numbers.index(7)}')
# numbers.reverse()
# print(f'1-4: reverse list 1 = {numbers}')
print(f'1-4: reverse list 2 = {numbers[::-1]}')
numbers.append(int(numbers[2]) + int(numbers[5]))
print(f'1-5: append index 2,5 = {numbers}')

print('Q-2 Data Type')
data = ['25', '3.14', 'True', '8', 'False']
data_new = [int(data[0]), float(data[1]), bool(data[2]) == True, int(data[3]), bool(data[4]) == False]
data_new_1 = [int(data[0]), float(data[1]), bool(data[2]), int(data[3]), bool("")]
print(f'Real data types solution 1:{data_new}')
print(f'Real data types solution 2:{data_new_1}')

print('Q-3 Data Type')
data = (10,20,30,20,40,20,50)
print(f'1-3: reverse tuple 2 = {data[::-1]}')
# Out:
# {'code': 115, 'name': 'Mohammad Fakhralami', 'dairy': ['milk', 'cheese', 'yoghurt'], 'fruit': ['apple', 'potato', 'onion', 'tomato', 'avocado', 'blueberry'], 'food': 'kebab', 'location': {'number': 26, 'alley': 'vila 2'}}
# Q-1 Data Type
# 1-1: count 12 = 3
# 1-2: sort list = [1, 1, 3, 7, 7, 9, 12, 12, 12]
#      Real list = [12, 7, 12, 3, 7, 9, 1, 1, 12]
# 1-3: first index 7 = 1
# 1-4: reverse list 2 = [12, 1, 1, 9, 7, 3, 12, 7, 12]
# 1-5: append index 2,5 = [12, 7, 12, 3, 7, 9, 1, 1, 12, 21]
# Q-2 Data Type
# Real data types solution 1:[25, 3.14, True, 8, False]
# Real data types solution 2:[25, 3.14, True, 8, False]
# Q-3 Data Type
# 1-3: reverse tuple 2 = (50, 20, 40, 20, 30, 20, 10)
