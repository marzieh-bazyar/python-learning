# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/Lesson06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name:")
language = input("Enter your language: ")
age = input("Enter your age: ")
message = ""
if language == "en":
    message = "Hello, " +  name + "!"
elif language == "fa":
        message = "Salam, " +name + "!"
else:
      message = "Hi," + name + "!"
print(message)
age = int(age)
if age < 18:
    print("You can not participate in course.")
elif age>=18 and age <45:
    print("Welcom to course.")
else: print("Connect with admin")
# Out:
# Enter your name:mary
# Enter your language: en
# Enter your age: 46
# Hello, mary!
# Connect with admin
