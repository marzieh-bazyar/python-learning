# %% [markdown]
# <a href="https://colab.research.google.com/github/marzieh-bazyar/python-learning/blob/main/lesson01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question_1
student = {
    'name':'Sara',
    'age' : 17,
    'grade': 19.25,
    'city':'Tehran'
        }
# name value
print(student.get("name"))
print()
# grade value
print(student.get("grade"))
print()
# add passed key
student.update({'passed':True})
print(student)
print()
# change city value to Shiraz
student.update({'city':'Shiraz'})
print()
#student['city'] = 'Shiraz'
print(student)
print()
# print all keys
print(student.keys())
print()
# print all values
print(student.values())
print()
print()
# Question_2
product = {
    'name': 'laptop',
    'price': '35000000',
    'brand': 'Lenovo',
    'in_stock': True
    }
print(product)
print()
# add price
product['price'] = int(product['price']) + 5000000
print(product)
print()
# delete brand key
del product['brand']
print(product)
print()
# make a list of all keys
key_list = list(product.keys())
print(key_list)
print()
# make a list of all values
values_list = list(product.values())
print(values_list)
print()
# name in dictionary
print("name" in product)
print()
# Question_3
A = {2, 4, 6, 8, 10}
B = {4, 6, 8, 12, 14}
print(A)
print(B)
print(A | B)
print(A & B)
print(A - B)
print(B - A)
print(A ^ B)
print("10" in B)
print((A & B) <= A)
# Out:
# Sara
#
# 19.25
#
# {'name': 'Sara', 'age': 17, 'grade': 19.25, 'city': 'Tehran', 'passed': True}
#
#
# {'name': 'Sara', 'age': 17, 'grade': 19.25, 'city': 'Shiraz', 'passed': True}
#
# dict_keys(['name', 'age', 'grade', 'city', 'passed'])
#
# dict_values(['Sara', 17, 19.25, 'Shiraz', True])
#
#
# {'name': 'laptop', 'price': '35000000', 'brand': 'Lenovo', 'in_stock': True}
#
# {'name': 'laptop', 'price': 40000000, 'brand': 'Lenovo', 'in_stock': True}
#
# {'name': 'laptop', 'price': 40000000, 'in_stock': True}
#
# ['name', 'price', 'in_stock']
#
# ['laptop', 40000000, True]
#
# True
#
# {2, 4, 6, 8, 10}
# {4, 6, 8, 12, 14}
# {2, 4, 6, 8, 10, 12, 14}
# {8, 4, 6}
# {2, 10}
# {12, 14}
# {2, 10, 12, 14}
# False
# True
